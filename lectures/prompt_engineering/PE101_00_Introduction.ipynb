# %% [markdown]
# # Prompt Engineering 101

# %% [markdown]
# ---

# %% [markdown]
# ## Before we start
#
# ### Who am I?
#
# * ex-PhD student (absolutorium achieved)
# * ex-teaching assistant @ Unideb
# * ex-python developer @ HigherClick
# * ex-data scientist @ Lensa
# * data science manager @ Datapao
# * programmer (<a href="github.com/fulibacsi">github</a>)
#
# ### What are we gonna do?
#
# 1. Have fun!
# 2. Demistify LLMs.
# 3. Learn how to efficiently interact with them.
# 4. Conquer the world!
#
# ### Requirements?
#
# * Solve the weekly challenges.
# * Define a problem and solve it.
# * Write some docs about it.
# * Free your mind!

# %% [markdown]
# ---

# %% [markdown]
# ## Course Overview
#
# |Session|Title                           |Key Themes                                            |Competencies Gained                              |
# |-------|--------------------------------|------------------------------------------------------|-------------------------------------------------|
# |1      |The Cognitive Engine            |LLM Mechanics, Tokenization, Hallucinations, Ethics   |Mental Modeling, Risk Assessment                 |
# |2      |The Syntax of Semantics         |Prompt Frameworks (CO-STAR), Iterative Refinement     |Structured Communication, Zero/Few-Shot Prompting|
# |3      |Pattern-Based Engineering       |Vanderbilt Catalog, Persona, Interview, Templates     |Systematic Problem Solving, Context Management   |
# |4      |Advanced Reasoning Architectures|Chain of Thought (CoT), Tree of Thoughts (ToT)        |Complex Logic, Decomposition, Decision Making    |
# |5      |Knowledge & Synthesis (RAG)     |Retrieval Augmented Generation, NotebookLM, Perplexity|Research Synthesis, Fact-Checking, Tool Use      |
# |6      |Agents & The Future of Work     |Autonomous Agents, Loops, Privacy                     |Workflow Automation, Strategic Implementation    |

# %% [markdown]
# ---
